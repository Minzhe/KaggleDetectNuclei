# %% [markdown]
# # Kaggle detect nuclei

# %%
from utility import getResizeImage, getResizeMask, restoreImage, convert2Sub
from lib import unet
from lib.metrics import iou_metric_tf
from skimage.io import imshow


import matplotlib.pyplot as plt

TRAIN_PATH = '/Users/minzhe/Documents/Project/KaggleDetectNuclei/data/stage1_train/'
TEST_PATH = '/Users/minzhe/Documents/Project/KaggleDetectNuclei/data/stage1_test/'
# Out:
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Read data

# %%
X_train, ids_train, sizes_train = getResizeImage(path=TRAIN_PATH, height=256, width=256, channels=3)
# Out:
# Getting and resizing images ...
# 100%|██████████| 670/670 [00:10<00:00, 62.48it/s]

# %%
sizes_train
# Out:
# [(256, 256),
#  (256, 256),
#  (256, 320),
#  (256, 256),
#  (256, 320),
#  (360, 360),
#  (360, 360),
#  (520, 696),
#  (256, 256),
#  (256, 320),
#  (520, 696),
#  (256, 256),
#  (256, 256),
#  (256, 256),
#  (520, 696),
#  (256, 256),
#  (256, 256),
#  (360, 360),
#  (256, 256),
#  (256, 256),
#  (256, 256),
#  (360, 360),
#  (256, 256),
#  (256, 256),
#  (256, 256),
#  (256, 256),
#  (1024, 1024),
#  (360, 360),
#  (256, 256),
#  (256, 256),
#  (520, 696),
#  (256, 256),
#  (256, 256),
#  (256, 256),
#  (360, 360),
#  (256, 256),
#  (256, 256),
#  (256, 256),
#  (256, 256),
#  (256, 256),
#  (256, 256),
#  (256, 256),
#  (256, 256),
#  (256, 256),
#  (256, 256),
#  (520, 696),
#  (256, 320),
#  (360, 360),
#  (256, 256),
#  (256, 320),
#  (256, 256),
#  (360, 360),
#  (256, 256),
#  (256, 256),
#  (256, 320),
#  (256, 320),
#  (360, 360),
#  (360, 360),
#  (256, 256),
#  (256, 256),
#  (256, 256),
#  (256, 256),
#  (256, 256),
#  (256, 256),
#  (360, 360),
#  (256, 256),
# ...

# %%
y_train = getResizeMask(path=TRAIN_PATH, height=128, width=128)

# %%
X_test = getResizeImage(path=TEST_PATH, height=128, width=128, channels=3)
# Out:
# Getting and resizing images ...
# 100%|██████████| 65/65 [00:01<00:00, 56.61it/s]

# %%
X_train[1].shape
# Out:
# (128, 128, 3)

# %%
imshow(X_train[1])
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
imshow(np.squeeze(y_train[1]))
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "

# %%
imshow(X_test[5])
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
